# %%
import cv2

# %%
img = cv2.imread('img1.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

haar_cascade = cv2.CascadeClassifier('haar_face.xml')

# Increase minNeighbors to 2 will decrease the number of false detected face
faces_rect = haar_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=2)
faces_rect
# Out:
# array([[1055,  207,   79,   79],
#        [ 910,  206,   82,   82],
#        [1218,  261,   73,   73],
#        [ 748,  230,   92,   92],
#        [1558,  248,   79,   79],
#        [ 454,  262,   77,   77],
#        [1725,  263,   75,   75],
#        [ 580,  278,   71,   71],
#        [1894,  289,   74,   74],
#        [2039,  202,   77,   77],
#        [1376,  251,   74,   74],
#        [2419,  270,   85,   85],
#        [1019,  197,   98,   98],
#        [1977,  588,   26,   26],
#        [2288,  500,   47,   47],
#        [1713,  561,   55,   55],
#        [1070,  500,   73,   73],
#        [ 782,  515,   55,   55],
#        [1926,  473,   69,   69],
#        [ 929,  489,   73,   73],
#        [1272,  528,   71,   71],
#        [1436,  591,   77,   77],
#        [1864,  596,   70,   70],
#        [1220,  594,   77,   77],
#        [1607,  601,   70,   70],
#        [  82,  611,   58,   58],
#        [ 510,  613,   76,   76],
#        [1955,  529,  269,  269],
#        [1868,  761,   57,   57],
#        [ 986,  808,   49,   49],
#        [1231,  763,   72,   72],
#        [ 914,  798,   71,   71],
#        [1106,  629,   64,   64],
#        [ 503,  868,   78,   78]], dtype=int32)

# %%
faces_rect[0]
# Out:
# array([1055,  207,   79,   79], dtype=int32)

# %%
for i in range(len(faces_rect)):
  x,y,w,h = faces_rect[i]
  cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), thickness=2)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
